# %% [markdown]
# # INFO 103: Introduction to data science <br> Demo \# 7: Visualization <br> Author: JRW

# %%
import json
import numpy as np
import re
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
import datetime
from IPython.display import HTML

# %% [markdown]
# ### Mission and setup
# In this workbook we're going to explore data visualization, using Python. This includes both static and interactive visualization. These features are available through different Python packages: static visualizations are generally covered well through matplotlib:
#
# `import matplotlib.pyplot as plt`
#
# which should be available with through Anaconda's distribution that includes Jupyter. A nice interactive visualizations library lives in the Bokeh package, which will likely need to be downloaded from a command line through pip:
#
# `pip install bokeh`
#
# or anaconda:
#
# `conda install bokeh`

# %% [markdown]
# #### Visualization in Python
# Outside of notebooks, baisc visualization in Python generally results in a separate graphics window opening up. Here's a really basic example of a Python histogram (generating some normal data) using pyplot that will work through any interactive python environment, notbooks or not.

# %%
mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('x')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Normal-data\ histogram:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

# %% [markdown]
# #### Where's the image?
# Generally, plotting with pyplot requires a specific request to show images. Outside of notebooks, this would cause a separate window to open up, forcing a Python terminal to hang, but Jupyter notebooks are a little nicer for this, and catch the images for you:

# %%
plt.show()

# %% [markdown]
# #### Do we really have to run `plt.show()` every time?
# Recalling our introductiont to Jupyter, there are 'magic' commands than can streamline plotting. In this case we can run the magic command `% matplotlib inline` to automatically ensure figures are shown.

# %%
% matplotlib inline

# %% [markdown]
# #### Figure dimensions
# Let's try this out without `plt.show()`, and adjust the figure size to be a little bit larger.

# %%
fig = plt.figure(figsize = (8,8))

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('x')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Normal-data\ histogram:}\ \mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

# %% [markdown]
# #### Getting the details right
# Now, even though all of the information is here in our figure, it's a little bit difficult to read the axes. Since visualization is all about communication, it's often better to push figure and axis titles and any other text towards the larger end. Since we have adjusted the figure dimensions to be larger, we now need to bring up the font sizes accordingly.

# %%
fig = plt.figure(figsize = (8,8))

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('x', fontsize = 18)
plt.ylabel('Probability', fontsize = 18)
plt.title(r'$\mathrm{Normal-data\ histogram:}\ \mu=100,\ \sigma=15$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.axis([40, 160, 0, 0.03])
plt.grid(True)

# %% [markdown]
# #### What about a legend?
# Right now we are not communicating any information that differentiates the histogram from the 'true' distribution red-dashed line (which we'll also make a bit bigger, for clarity). Let's build in a legend!

# %%
fig = plt.figure(figsize = (8,8))

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75, label = "Randomly generated data")

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth = 5, label = "'True' distribution", alpha = 0.5)

plt.xlabel('x', fontsize = 18)
plt.ylabel('Probability', fontsize = 18)
plt.title(r'$\mathrm{Normal-data\ histogram:}\ \mu=100,\ \sigma=15$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.axis([40, 160, 0, 0.035])
plt.grid(True)
plt.legend(fontsize = 18)

# %% [markdown]
# #### Can we keep it?
# Unless the purpose of a visualization is just for EDA, and it not specifically a result to be communicated, it's generally best to make hard copipes of visualizations, e.g., a png, jpeg, pdf, etcetera. Let's take this figure and write it out to a file as a pdf. Note: since pdf is a vector graphics format, this will figure will technically have infinite resolution!

# %%
fig = plt.figure(figsize = (8,8))

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75, label = "Randomly generated data")

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth = 2, label = "'True' distribution")

plt.xlabel('x', fontsize = 18)
plt.ylabel('Probability', fontsize = 18)
plt.title(r'$\mathrm{Normal-data\ histogram:}\ \mu=100,\ \sigma=15$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.axis([40, 160, 0, 0.035])
plt.grid(True)
plt.legend(fontsize = 18)

plt.savefig('./myAwesomeHistogram.pdf', bbox_inches='tight', pad_inches = .25)

# %% [markdown]
# #### Where's the pdf?
# We saved the pdf in the sam directory as this notebook. To bring this up, we can use a little bit of Python magic and run a command line:

# %%
# !open myAwesomeHistogram.pdf

# %% [markdown]
# #### Displaying pdfs in a notebook
# This is actually a little bit harder than displaying raster graphics with a notebook. However, we can just use a function that displays HTML (which is what we see in a notebook). Notice as well that since this is a vector graphic, it has the text embeded, which can be highlighted, copied/pasted, generally making the visualization a more interactive object than a raster.

# %%
HTML('<iframe src=./myAwesomeHistogram.pdf width=700 height=350></iframe>')
# Out:
# <iframe src=./myAwesomeHistogram.pdf width=700 height=350></iframe>

# %% [markdown]
# #### Other basic plot types
# So, we've actually seen a few other visualization types in the other notebooks. We've used pyplot for scatter and density plots, and adding legends, adjusting their fonts, and saving to file, etc., work exactly the same for those. So, here's a few other basic examples (all using pyplot), including a box plot and a time series:

# %%
fig = plt.figure(figsize = (8,8))

# fake up some awesome boxplot data with outliers
mu, sigma = 0, 15
x = np.concatenate((
    mu + sigma*np.random.randn(10000),
    mu + sigma*np.random.rand(25) - 100*(np.random.rand(25) - np.random.rand(25))
))

plt.boxplot(x)
plt.xticks([1], ['Group 1'])
plt.ylabel('x', fontsize = 18)
plt.title(r'$\mathrm{Normal-data\ box\ plot\ with\ outliers:}\ \mu=0,\ \sigma=15$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.grid(True)
plt.axis([0.5, 1.5, -110, 110])
# Out:
# [0.5, 1.5, -110, 110]

# %%
fig = plt.figure(figsize = (8,8))

## to make some timeseries data we'll have to use the datetime package!

minutes = np.random.randint(59, size = 24)

x = np.array([datetime.datetime(2017, 5, 26, i, minutes[i-1]) for i in range(1,24)])

t = np.array([(x[-1] - x[i]).seconds/float((x[-1] - x[0]).seconds) for i, _ in enumerate(x)])

y = np.sin(3*2*np.pi*t)

plt.plot(x,y,color = "red", linestyle = 'dashed', linewidth = 2)
plt.plot_date(x,y, color = 'black')
plt.xticks(rotation=70)

plt.ylabel('Amplitude', fontsize = 18)
plt.xlabel('Time of day', fontsize = 18)
plt.title(r'$\mathrm{Sine\ as\ a\ time\ series:}$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.grid(True)

# %% [markdown]
# #### These different plots all have their nuances
# For example, we may want to display multiple box plots side-by-side!

# %%
fig = plt.figure(figsize = (8,8))

# fake up some awesome boxplot data with outliers
mu, sigma = 0, 15
x = np.concatenate((
    mu + sigma*np.random.randn(10000),
    mu + sigma*np.random.rand(25) - 100*(np.random.rand(25) - np.random.rand(25))
))

data = [x, np.array(x) + 25, np.array(x) - 25]

plt.boxplot(data)
plt.xticks([1, 2, 3], ['Group 1', 'Group 2', 'Group 3'])
plt.ylabel('x', fontsize = 18)
plt.title(r'$\mathrm{Multiple\ box\ plots\ with\ outliers}$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.grid(True)
plt.axis([0.5, 3.5, -135, 135])
# Out:
# [0.5, 3.5, -135, 135]

# %% [markdown]
# #### Putting things together
# Sometimes it's nice to make a figure that has multiple plot all next to one another, It may help to get things into a report snugly, or it may be that twi figures share an axis and are best placed side-by-side (like our multiple box plots) for comparision. Let's put all three next to one another.

# %%
fig = plt.figure(figsize = (8,8))

# position the first figure
first_ax = fig.add_axes([0, 0, 1, 0.45])

## to make some timeseries data we'll have to use the datetime package!

minutes = np.random.randint(59, size = 24)

x = np.array([datetime.datetime(2017, 5, 26, i, minutes[i-1]) for i in range(1,24)])
y = np.random.randint(100, size=x.shape)

t = np.array([(x[-1] - x[i]).seconds/float((x[-1] - x[0]).seconds) for i, _ in enumerate(x)])

y = np.sin(3*2*np.pi*t)

plt.plot(x,y,color = "red", linestyle = 'dashed', linewidth = 2)
plt.plot_date(x,y, color = 'black')
plt.xticks(rotation=70)

plt.ylabel('Amplitude', fontsize = 18)
plt.xlabel('Time of day', fontsize = 18)
plt.title(r'$\mathrm{Sine\ as\ a\ time\ series:}$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.grid(True)

# position the second figure
second_ax = fig.add_axes([0, 0.55, 0.425, 0.45])

# fake up some awesome boxplot data with outliers
mu, sigma = 0, 15
x = np.concatenate((
    mu + sigma*np.random.randn(10000),
    mu + sigma*np.random.rand(25) - 100*(np.random.rand(25) - np.random.rand(25))
))

data = [x, np.array(x) + 25, np.array(x) - 25]

plt.boxplot(data)
plt.xticks([1, 2, 3], ['Group 1', 'Group 2', 'Group 3'])
plt.ylabel('x', fontsize = 18)
plt.title(r'$\mathrm{Box\ plots\ with\ outliers}$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.grid(True)
plt.axis([0.5, 3.5, -135, 135])

# position the second figure
third_ax = fig.add_axes([0.575, 0.55, 0.425, 0.45])

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75, label = "Randomly generated data")

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth = 2, label = "'True' distribution")

plt.xlabel('x', fontsize = 18)
plt.ylabel('Probability', fontsize = 18)
plt.title(r'$\mathrm{Normal-data\ histogram}$', fontsize = 18)
plt.tick_params(labelsize=18)
plt.axis([40, 160, 0, 0.03])
plt.yticks(rotation=45)
plt.grid(True)

# %% [markdown]
# ### Interactivity
# Here, we're going to take a quick look a bokeh's interactive capabilities. To get things started we have to do some package imports:

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure
from bokeh.io import push_notebook, show, output_notebook

# %% [markdown]
# #### Some notes
# We'll start with a static visualization, but since the goal with bokeh is interactivity, it natively renders as html. Thus, when we use bokeh's `show()` functon, it will always display in a browser window, whether or not we choose to embed it in our notebook. Here's a fixed, normal histogram that will open up a separate browser window!

# %%
params = [0, 0.5]

p = figure(tools="save",background_fill_color="#E8DDCB")

p.title.text="Normal Distribution (μ="+str(params[0])+", σ="+str(params[1])+")"

measured = np.random.normal(params[0], params[1], 1000)
hist, edges = np.histogram(measured, density=True, bins=50)

x = np.linspace(-2, 2, 1000)
pdf = 1/(params[1] * np.sqrt(2*np.pi)) * np.exp(-(x-params[0])**2 / (2*params[1]**2))

pdf = mlab.normpdf(edges, params[0],params[1])

h = p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
l = p.line(edges, pdf, line_color="#D95B43", line_width=3, alpha=0.7, legend="PDF")

p.legend.location = "top_left"
p.xaxis.axis_label = 'x'
p.yaxis.axis_label = 'Pr(x)'
t = show(
    gridplot(p, ncols=1, plot_width=600, plot_height=600, toolbar_location=None), 
    notebook_handle = True
)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="64af93a1-470a-4a79-87d3-059f9687e11a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("64af93a1-470a-4a79-87d3-059f9687e11a").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("fc376061-77b2-4209-8cdf-cbd66904e2e6", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("64af93a1-470a-4a79-87d3-059f9687e11a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '64af93a1-470a-4a79-87d3-059f9687e11a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c81dd905-c01d-4f0d-9dbd-e59de2e5a351":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[51]},"y":{"__ndarray__":"...","dtype":"float64","shape":[51]}}},"id":"9943e523-8efc-4016-8874-96e69c74d590","type":"ColumnDataSource"},{"attributes":{},"id":"30e65b1b-b4a3-4f86-880f-569292efe4ed","type":"BasicTicker"},{"attributes":{"callback":null},"id":"3d3f2e03-aa76-4d33-9512-ba2264eff1c3","type":"DataRange1d"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"8d099965-c8a1-4584-97bb-95187b9ac436","type":"LinearAxis"}],"left":[{"id":"e9f84876-ea41-4896-981d-d67f8d725e25","type":"LinearAxis"}],"renderers":[{"id":"8d099965-c8a1-4584-97bb-95187b9ac436","type":"LinearAxis"},{"id":"2ed0f464-a15f-47c4-9bab-f8b339aa1f74","type":"Grid"},{"id":"e9f84876-ea41-4896-981d-d67f8d725e25","type":"LinearAxis"},{"id":"7edf33b4-26d4-46c7-b7d6-418248bb5bd3","type":"Grid"},{"id":"f5a5c589-9114-48ae-a682-7843bccbf61a","type":"GlyphRenderer"},{"id":"0b0f73ba-a70f-41c2-84a5-dcffda512a36","type":"Legend"},{"id":"c72fa052-d6e1-41b7-9847-02f5af83592f","type":"GlyphRenderer"}],"title":{"id":"46570f11-6e26-45e9-8149-2497f1eb0e4d","type":"Title"},"tool_events":{"id":"5b2e1962-8c4c-4079-9c06-33322d4dec15","type":"ToolEvents"},"toolbar":{"id":"f63d875b-2f09-4b06-8a26-39fcac669f76","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"6aebee28-e630-4552-830b-7527e8bd46f2","type":"DataRange1d"},"y_range":{"id":"3d3f2e03-aa76-4d33-9512-ba2264eff1c3","type":"DataRange1d"}},"id":"20ffe7c2-044f-4ad6-9895-ad968d829714","subtype":"Figure","type":"Plot"},{"attributes":{"axis_label":"x","formatter":{"id":"cbf51759-2a70-4b2f-9c2a-ca0a35206af9","type":"BasicTickFormatter"},"plot":{"id":"20ffe7c2-044f-4ad6-9895-ad968d829714","subtype":"Figure","type":"Plot"},"ticker":{"id":"d092d64a-6126-469e-96ce-62cbc2830a7e","type":"BasicTicker"}},"id":"8d099965-c8a1-4584-97bb-95187b9ac436","type":"LinearAxis"},{"attributes":{"bottom":{"value":0},"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"left":{"field":"left"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"right":{"field":"right"},"top":{"field":"top"}},"id":"27a798ae-f1ca-4cc4-891a-a855eae3239b","type":"Quad"},{"attributes":{"data_source":{"id":"bc81fdc9-552c-4370-964e-1e6e535024c4","type":"ColumnDataSource"},"glyph":{"id":"faa44a22-3a3c-411a-9d37-1894ec42f161","type":"Quad"},"hover_glyph":null,"nonselection_glyph":{"id":"27a798ae-f1ca-4cc4-891a-a855eae3239b","type":"Quad"},"selection_glyph":null},"id":"f5a5c589-9114-48ae-a682-7843bccbf61a","type":"GlyphRenderer"},{"attributes":{},"id":"281b8778-c91c-4d9c-8841-711e81eee913","type":"BasicTickFormatter"},{"attributes":{"data_source":{"id":"9943e523-8efc-4016-8874-96e69c74d590","type":"ColumnDataSource"},"glyph":{"id":"2fae5d9d-3bfe-4756-9073-a46d7668624c","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"dcfeb934-4ef0-4bab-b6c9-3cda685de4d6","type":"Line"},"selection_glyph":null},"id":"c72fa052-d6e1-41b7-9847-02f5af83592f","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"6628c533-4d89-4714-a5e0-f3069e4e9eb3","type":"SaveTool"}]},"id":"f63d875b-2f09-4b06-8a26-39fcac669f76","type":"Toolbar"},{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"faa44a22-3a3c-411a-9d37-1894ec42f161","type":"Quad"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"bc81fdc9-552c-4370-964e-1e6e535024c4","type":"ColumnDataSource"},{"attributes":{},"id":"d092d64a-6126-469e-96ce-62cbc2830a7e","type":"BasicTicker"},{"attributes ...

# %% [markdown]
# #### Embedding in a notebook
# Much like there is a magic command to have matplotlib automatically have figures embed in a notebook, we can run `output_notebook()` to have bokeh embed right here:

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c155695f-8645-4ec4-936d-3b80bc9e5208">Loading BokehJS ...</span>
#     </div>

# %%
params = [0, 0.5]

p = figure(tools="save",background_fill_color="#E8DDCB")

p.title.text="Normal Distribution (μ="+str(params[0])+", σ="+str(params[1])+")"

measured = np.random.normal(params[0], params[1], 1000)
hist, edges = np.histogram(measured, density=True, bins=50)

x = np.linspace(-2, 2, 1000)
pdf = 1/(params[1] * np.sqrt(2*np.pi)) * np.exp(-(x-params[0])**2 / (2*params[1]**2))

pdf = mlab.normpdf(edges, params[0],params[1])

h = p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
        fill_color="#036564", line_color="#033649")
l = p.line(edges, pdf, line_color="#D95B43", line_width=3, alpha=0.7, legend="PDF")

p.x_range.start = -5
p.x_range.end = 5

p.y_range.start = 0
p.y_range.end = 1

p.legend.location = "top_left"
p.xaxis.axis_label = 'x'
p.yaxis.axis_label = 'Pr(x)'
t = show(gridplot(p, ncols=1, plot_width=600, plot_height=600, toolbar_location=None), notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="c9baaa8d-5ec2-4c38-afb9-296bf6146eda"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("c9baaa8d-5ec2-4c38-afb9-296bf6146eda").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("cfa36bce-36e5-4558-bf94-90bd68c23da0", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("c9baaa8d-5ec2-4c38-afb9-296bf6146eda");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'c9baaa8d-5ec2-4c38-afb9-296bf6146eda' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f0ced7f8-5e5f-4cc1-aeee-bb654f4fe771":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2661fe49-0878-42e3-8ab6-6a5f9ae3e961","type":"Quad"},{"attributes":{"label":{"value":"PDF"},"renderers":[{"id":"17525ad4-b798-46db-8522-77ead7e12329","type":"GlyphRenderer"}]},"id":"36fd0d96-12b0-4059-b92f-c8a8606c9cd0","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b5220bf7-ee59-4c49-8183-961a3b2f1d1c","type":"SaveTool"}]},"id":"8a3c0c29-0bb3-40e2-bba5-6bcad4b270a6","type":"Toolbar"},{"attributes":{"children":[{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"}]},"id":"adf6ec5e-68cf-4dc0-895b-b8b841ce4480","type":"Row"},{"attributes":{"callback":null,"end":1,"start":0},"id":"1c0f97dd-dc1a-4f50-b6a6-bd90ae174a6a","type":"DataRange1d"},{"attributes":{},"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"041d5bd4-ceb7-48fe-a597-003b858ae588","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"}},"id":"b5220bf7-ee59-4c49-8183-961a3b2f1d1c","type":"SaveTool"},{"attributes":{},"id":"8894b652-65d5-4009-b758-43be7e3ff16a","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Normal Distribution (\u03bc=0, \u03c3=0.5)"},"id":"a2f9906e-584e-4043-af03-e37777982108","type":"Title"},{"attributes":{"children":[{"id":"adf6ec5e-68cf-4dc0-895b-b8b841ce4480","type":"Row"}]},"id":"f81eac0d-01f5-4960-a9a1-342c4af83380","type":"Column"},{"attributes":{"callback":null,"end":5,"start":-5},"id":"faf1b154-68ad-4b9b-a7f0-4e14b1010335","type":"DataRange1d"},{"attributes":{},"id":"63de8997-4831-4204-81a6-b973a8d506d9","type":"ToolEvents"},{"attributes":{"data_source":{"id":"2e74adf6-3392-499b-9fe8-926cf5f06e25","type":"ColumnDataSource"},"glyph":{"id":"86e52be8-3309-4814-a949-0952e7ebdafe","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b6a0743d-64d8-4791-a45e-674dc11bd04f","type":"Line"},"selection_glyph":null},"id":"17525ad4-b798-46db-8522-77ead7e12329","type":"GlyphRenderer"},{"attributes":{"axis_label":"x","formatter":{"id":"fdddcc36-15c1-47ce-9d2d-299400f62b5d","type":"BasicTickFormatter"},"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"8894b652-65d5-4009-b758-43be7e3ff16a","type":"BasicTicker"}},"id":"4a396bd2-f240-43a1-8064-424155b0e590","type":"LinearAxis"},{"attributes":{"axis_label":"Pr(x)","formatter":{"id":"369ad97f-2498-4ef2-9773-8baf6a16ffec","type":"BasicTickFormatter"},"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"}},"id":"342c1849-8d64-4dac-a373-32cdd19f7665","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"}},"id":"b76fe9f6-c694-4088-a955-ec67277b23cb","type":"Grid"},{"attributes":{"line_alpha":{"value":0.7},"line_color":{"value":"#D95B43"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"86e52be8-3309-4814-a949-0952e7ebdafe","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6a0743d-64d8-4791-a45e-674dc11bd04f","type":"Line"},{"attributes":{},"id":"369ad97f-2498-4ef2-9773-8baf6a16ffec","type":"BasicTickFormatter"},{"attributes":{"background_fill_color":{"value":" ...

# %% [markdown]
# #### Updating bokeh figures
# The goal being interactivity, bokeh figures can be updated. This can be done in our notebook with the `push_notebook()` function. Let's modify the shape of our data and distribution with $\mu$ and $\sigma$!

# %%
params[0] = 1.25
params[1] = 0.5

measured = np.random.normal(params[0], params[1], 1000)
hist, edges = np.histogram(measured, density=True, bins=50)

x = np.linspace(min(measured), max(measured), 1000)
pdf = mlab.normpdf(edges, params[0],params[1])

l.data_source.data['x'] = edges
l.data_source.data['y'] = pdf
h.data_source.data['top'] = hist
h.data_source.data['left'] = edges[:-1] 
h.data_source.data['right'] = edges[1:]

p.title.text="Normal Distribution (μ="+str(params[0])+", σ="+str(params[1])+")"

push_notebook(handle = t)

# %% [markdown]
# #### Making things interactive
# Now that we can update our figure, we have to package the update into a function. Then, whenever we execute the function, the figure will update:

# %%
def histUpdate(mu, sigma):
    params[0] = mu
    params[1] = sigma

    measured = np.random.normal(params[0], params[1], 1000)
    hist, edges = np.histogram(measured, density=True, bins=50)

    x = np.linspace(min(measured), max(measured), 1000)
    pdf = mlab.normpdf(edges, params[0],params[1])

    l.data_source.data['x'] = edges
    l.data_source.data['y'] = pdf
    h.data_source.data['top'] = hist
    h.data_source.data['left'] = edges[:-1] 
    h.data_source.data['right'] = edges[1:]

    p.title.text="Normal Distribution (μ="+str(params[0])+", σ="+str(params[1])+")"

    push_notebook(handle = t)

# %% [markdown]
# Now, let's re-show our figure right here and test out the function:

# %%
t = show(gridplot(p, ncols=1, plot_width=600, plot_height=600, toolbar_location=None), notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="1d3554a6-45d8-42ae-b99e-15e0f62c50f1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("1d3554a6-45d8-42ae-b99e-15e0f62c50f1").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("77de2dc1-b122-488c-810c-8a1580a9c7e4", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1d3554a6-45d8-42ae-b99e-15e0f62c50f1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1d3554a6-45d8-42ae-b99e-15e0f62c50f1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f51e29bd-3462-4c9b-ae80-0d7d2074fcdd":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2661fe49-0878-42e3-8ab6-6a5f9ae3e961","type":"Quad"},{"attributes":{"label":{"value":"PDF"},"renderers":[{"id":"17525ad4-b798-46db-8522-77ead7e12329","type":"GlyphRenderer"}]},"id":"36fd0d96-12b0-4059-b92f-c8a8606c9cd0","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b5220bf7-ee59-4c49-8183-961a3b2f1d1c","type":"SaveTool"}]},"id":"8a3c0c29-0bb3-40e2-bba5-6bcad4b270a6","type":"Toolbar"},{"attributes":{"callback":null,"end":1,"start":0},"id":"1c0f97dd-dc1a-4f50-b6a6-bd90ae174a6a","type":"DataRange1d"},{"attributes":{},"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"041d5bd4-ceb7-48fe-a597-003b858ae588","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"}},"id":"b5220bf7-ee59-4c49-8183-961a3b2f1d1c","type":"SaveTool"},{"attributes":{},"id":"8894b652-65d5-4009-b758-43be7e3ff16a","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Normal Distribution (\u03bc=1.25, \u03c3=0.5)"},"id":"a2f9906e-584e-4043-af03-e37777982108","type":"Title"},{"attributes":{"callback":null,"end":5,"start":-5},"id":"faf1b154-68ad-4b9b-a7f0-4e14b1010335","type":"DataRange1d"},{"attributes":{},"id":"63de8997-4831-4204-81a6-b973a8d506d9","type":"ToolEvents"},{"attributes":{"data_source":{"id":"2e74adf6-3392-499b-9fe8-926cf5f06e25","type":"ColumnDataSource"},"glyph":{"id":"86e52be8-3309-4814-a949-0952e7ebdafe","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b6a0743d-64d8-4791-a45e-674dc11bd04f","type":"Line"},"selection_glyph":null},"id":"17525ad4-b798-46db-8522-77ead7e12329","type":"GlyphRenderer"},{"attributes":{"axis_label":"x","formatter":{"id":"fdddcc36-15c1-47ce-9d2d-299400f62b5d","type":"BasicTickFormatter"},"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"8894b652-65d5-4009-b758-43be7e3ff16a","type":"BasicTicker"}},"id":"4a396bd2-f240-43a1-8064-424155b0e590","type":"LinearAxis"},{"attributes":{"axis_label":"Pr(x)","formatter":{"id":"369ad97f-2498-4ef2-9773-8baf6a16ffec","type":"BasicTickFormatter"},"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"}},"id":"342c1849-8d64-4dac-a373-32cdd19f7665","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"}},"id":"b76fe9f6-c694-4088-a955-ec67277b23cb","type":"Grid"},{"attributes":{"line_alpha":{"value":0.7},"line_color":{"value":"#D95B43"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"86e52be8-3309-4814-a949-0952e7ebdafe","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6a0743d-64d8-4791-a45e-674dc11bd04f","type":"Line"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[51]},"y":{"__ndarray__":"...","dtype":"float64","shape":[51]}}},"id":"2e74adf6-3392-499b-9fe8-926cf5f06e25","type":"ColumnDataSource"},{"attributes":{},"id":"369ad97f-2498-4ef2-9773-8baf6a16ffec","type":"BasicTickFormatter"},{"attributes":{"background_fill_color":{"value":"#E8DDCB"},"below":[{"id":"4a396bd2-f240-43a1-8064-424155b0e59 ...

# %%
histUpdate(3, 0.5)

# %% [markdown]
# #### Wrapping our function in a GUI
# Now that we have our function, we can use sliders to adjust the mean and standard deviation of our histogram. The widget we'll use comes from ipython:

# %%
from ipywidgets import interact

# %% [markdown]
# Now, we just need to launch the ipython widget:

# %%
interact(histUpdate, mu = (-4,4), sigma = (0.05,5))

# %%
t = show(gridplot(p, ncols=1, plot_width=400, plot_height=400, toolbar_location=None), notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="ad3dd93e-5ce7-48ab-bcce-00ee44bc2869"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("ad3dd93e-5ce7-48ab-bcce-00ee44bc2869").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("cca633c1-21c4-42db-acdc-cd1fc3f713bb", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("ad3dd93e-5ce7-48ab-bcce-00ee44bc2869");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'ad3dd93e-5ce7-48ab-bcce-00ee44bc2869' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"578a6594-07a0-4ada-9897-244f868d8dfa":{"roots":{"references":[{"attributes":{"bottom":{"value":0},"fill_color":{"value":"#036564"},"left":{"field":"left"},"line_color":{"value":"#033649"},"right":{"field":"right"},"top":{"field":"top"}},"id":"2661fe49-0878-42e3-8ab6-6a5f9ae3e961","type":"Quad"},{"attributes":{"label":{"value":"PDF"},"renderers":[{"id":"17525ad4-b798-46db-8522-77ead7e12329","type":"GlyphRenderer"}]},"id":"36fd0d96-12b0-4059-b92f-c8a8606c9cd0","type":"LegendItem"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"b5220bf7-ee59-4c49-8183-961a3b2f1d1c","type":"SaveTool"}]},"id":"8a3c0c29-0bb3-40e2-bba5-6bcad4b270a6","type":"Toolbar"},{"attributes":{"callback":null,"end":1,"start":0},"id":"1c0f97dd-dc1a-4f50-b6a6-bd90ae174a6a","type":"DataRange1d"},{"attributes":{},"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["right","top","left"],"data":{"left":{"__ndarray__":"...","dtype":"float64","shape":[50]},"right":{"__ndarray__":"...","dtype":"float64","shape":[50]},"top":{"__ndarray__":"...","dtype":"float64","shape":[50]}}},"id":"041d5bd4-ceb7-48fe-a597-003b858ae588","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"}},"id":"b5220bf7-ee59-4c49-8183-961a3b2f1d1c","type":"SaveTool"},{"attributes":{},"id":"8894b652-65d5-4009-b758-43be7e3ff16a","type":"BasicTicker"},{"attributes":{"plot":null,"text":"Normal Distribution (\u03bc=0, \u03c3=2.525)"},"id":"a2f9906e-584e-4043-af03-e37777982108","type":"Title"},{"attributes":{"callback":null,"end":5,"start":-5},"id":"faf1b154-68ad-4b9b-a7f0-4e14b1010335","type":"DataRange1d"},{"attributes":{"children":[{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"}]},"id":"517414ab-e130-4ec8-96ca-6d3bd148ace3","type":"Row"},{"attributes":{"children":[{"id":"517414ab-e130-4ec8-96ca-6d3bd148ace3","type":"Row"}]},"id":"fe03b654-8cda-442a-ac9e-417dcd87b1cb","type":"Column"},{"attributes":{"data_source":{"id":"2e74adf6-3392-499b-9fe8-926cf5f06e25","type":"ColumnDataSource"},"glyph":{"id":"86e52be8-3309-4814-a949-0952e7ebdafe","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"b6a0743d-64d8-4791-a45e-674dc11bd04f","type":"Line"},"selection_glyph":null},"id":"17525ad4-b798-46db-8522-77ead7e12329","type":"GlyphRenderer"},{"attributes":{"axis_label":"x","formatter":{"id":"fdddcc36-15c1-47ce-9d2d-299400f62b5d","type":"BasicTickFormatter"},"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"8894b652-65d5-4009-b758-43be7e3ff16a","type":"BasicTicker"}},"id":"4a396bd2-f240-43a1-8064-424155b0e590","type":"LinearAxis"},{"attributes":{"axis_label":"Pr(x)","formatter":{"id":"369ad97f-2498-4ef2-9773-8baf6a16ffec","type":"BasicTickFormatter"},"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"}},"id":"342c1849-8d64-4dac-a373-32cdd19f7665","type":"LinearAxis"},{"attributes":{"dimension":1,"plot":{"id":"ef8eea14-269e-4d1d-886d-2f3b0e9614b0","subtype":"Figure","type":"Plot"},"ticker":{"id":"fadf3a29-366c-4023-9166-da59f5c52825","type":"BasicTicker"}},"id":"b76fe9f6-c694-4088-a955-ec67277b23cb","type":"Grid"},{"attributes":{"line_alpha":{"value":0.7},"line_color":{"value":"#D95B43"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"86e52be8-3309-4814-a949-0952e7ebdafe","type":"Line"},{"attributes":{},"id":"63de8997-4831-4204-81a6-b973a8d506d9","type":"ToolEvents"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":3},"x":{"field":"x"},"y":{"field":"y"}},"id":"b6a0743d-64d8-4791-a45e-674dc11bd04f","type":"Line"},{"attributes":{},"id":"369ad97f-2498-4ef2-9773-8baf6a16ffec","type":"BasicTickFormatter"},{"attributes":{"background_fill_color":{"value" ...

# %% [markdown]
# #### Where to go from here?
# For simplicity, we used an iPython widget, which is kind of cheating, since a big goal of Bokeh is to launch interactive web apps as general webpages. These won't have any iPython/Jupyter capability, so widgets like sliders or rollovers or textboxes or have to be built more directly as browser apps. Since browsers can't run Python code, Bokeh is really only every wrapping javascript! This means that custom Bokeh graphics requires dealing with a little more javasript. However, Bokeh does provide some basic widgets which can be used through writing Python, only, though they are still a little more complicated than that presented above. For more information, check out
# * http://bokeh.pydata.org/en/latest/docs/user_guide/interaction/widgets.html
